# %%
import numpy as np
import numpy.typing as npt
import pandas as pd
import tensorflow as tf
import os

from matplotlib import pyplot as plt
from scipy.special import erf
from typing import Union 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import roc_curve, auc
from keras.models import Model
from keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, Flatten, Dense, Dropout, Concatenate, Reshape
from tqdm import tqdm
# Out:
# 2024-06-02 23:14:50.456563: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Simulated Flares
class_info = pd.read_csv('sim3/simulated_flares.csv')
ids = [i for i in class_info['identifier']]
peak_count = [int(count) for count in class_info['peak_count']]

data = []
labels = []

for i in ids:
    tod = pd.read_csv('sim3/flares/' + f'{i}' + '.csv')
    data.append(list(tod['Counts']))
    
for index in range(len(class_info)):
    if str(class_info['flare_type'][index]) == 'A':
        labels.append(0)
    if str(class_info['flare_type'][index]) == 'B':
        labels.append(1)
    else:
        continue
data = pad_sequences(data, padding='post', dtype=float)

# %%
# Derivative of the light curve
data_deriv = [ (data[i][1:] - data[i][:-1]) for i in range(len(data)) ] 

data_deriv = pad_sequences(data_deriv, padding='post', dtype=float)

print(data_deriv[0])
print(data_deriv.shape)
print(type(data_deriv[0, 0]))
# Out:
# [-0.00328779 -0.00327313 -0.00325786 ...  0.          0.
#   0.        ]
# (1000, 1998)
# <class 'numpy.float64'>

# %%
model1 = Sequential()
    
# First convolutional layer
model1.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(len(data[0]), 1)))
model1.add(MaxPooling1D(pool_size=2))

# Second convolutional layer
model1.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model1.add(MaxPooling1D(pool_size=2))

# Third convolutional layer
model1.add(Conv1D(filters=256, kernel_size=3, activation='relu'))
model1.add(MaxPooling1D(pool_size=2))

# Flatten the output
model1.add(Flatten())

# Fully connected layer
model1.add(Dense(128, activation='relu'))
model1.add(Dropout(0.5))

# Output layer
model1.add(Dense(1, activation='sigmoid'))

# Compile the model
model1.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
model1.fit(np.array(data), np.array(labels), epochs=100, batch_size=32, validation_split=0.2, verbose=1)


model2 = Sequential()

# First convolutional layer
model2.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(len(data_deriv[0]), 1)))
model2.add(MaxPooling1D(pool_size=2))

# Second convolutional layer
model2.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model2.add(MaxPooling1D(pool_size=2))

# Third convolutional layer
model2.add(Conv1D(filters=256, kernel_size=3, activation='relu'))
model2.add(MaxPooling1D(pool_size=2))

# Flatten the output
model2.add(Flatten())

# Fully connected layer
model2.add(Dense(128, activation='relu'))
model2.add(Dropout(0.5))

# Output layer
model2.add(Dense(1, activation='sigmoid'))

# Compile the model
model2.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
model2.fit(np.array(data_deriv), np.array(labels), epochs=100, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# 2024-06-02 23:14:57.698167: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10398 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:89:00.0, compute capability: 6.1
# Epoch 1/100
# 2024-06-02 23:15:00.057602: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2024-06-02 23:15:00.744044: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f2ca7716fc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-06-02 23:15:00.744096: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2024-06-02 23:15:00.754147: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-06-02 23:15:01.007961: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 25/25 [==============================] - 6s 28ms/step - loss: 61.8653 - accuracy: 0.5362 - val_loss: 2.4925 - val_accuracy: 0.5200
# Epoch 2/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.7720 - accuracy: 0.6850 - val_loss: 0.6904 - val_accuracy: 0.6800
# Epoch 3/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.5610 - accuracy: 0.7487 - val_loss: 0.6057 - val_accuracy: 0.7100
# Epoch 4/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.4706 - accuracy: 0.7925 - val_loss: 0.5843 - val_accuracy: 0.7300
# Epoch 5/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.4156 - accuracy: 0.8200 - val_loss: 0.5717 - val_accuracy: 0.7400
# Epoch 6/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.4717 - accuracy: 0.8163 - val_loss: 0.5711 - val_accuracy: 0.7800
# Epoch 7/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.3684 - accuracy: 0.8325 - val_loss: 1.0589 - val_accuracy: 0.6850
# Epoch 8/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.4272 - accuracy: 0.8112 - val_loss: 0.9391 - val_accuracy: 0.6750
# Epoch 9/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.3851 - accuracy: 0.8375 - val_loss: 0.7251 - val_accuracy: 0.7300
# Epoch 10/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.4976 - accuracy: 0.8062 - val_loss: 0.6328 - val_accuracy: 0.7350
# Epoch 11/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.4550 - accuracy: 0.8200 - val_loss: 0.8121 - val_accuracy: 0.7250
# Epoch 12/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.3190 - accuracy: 0.8587 - val_loss: 0.8179 - val_accuracy: 0.7100
# Epoch 13/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2705 - accuracy: 0.8913 - val_loss: 0.9391 - val_accuracy: 0.7250
# Epoch 14/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2951 - accuracy: 0.8825 - val_loss: 0.9694 - val_accuracy: 0.7400
# Epoch 15/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.2517 - accuracy: 0.8838 - val_loss: 0.9371 - val_accuracy: 0.7200
# Epoch 16/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.2369 - accuracy: 0.9038 - val_loss: 1.0781 - val_accuracy: 0.7300
# Epoch 17/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2140 - accuracy: 0.9087 - val_loss: 0.9842 - val_accuracy: 0.7250
# Epoch 18/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2238 - accuracy: 0.8838 - val_loss: 0.9250 - val_accuracy: 0.7500
# Epoch 19/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2093 - accuracy: 0.9262 - val_loss: 1.0984 - val_accuracy: 0.7500
# Epoch 20/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2164 - accuracy: 0.9187 - val_loss: 1.1261 - val_accuracy: 0.7400
# Epoch 21/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2365 - accuracy: 0.9038 - val_loss: 1.3363 - val_accuracy: 0.7300
# Epoch 22/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2688 - accuracy: 0.9087 - val_loss: 1.3697 - val_accuracy: 0.7450
# Epoch 23/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2015 - accuracy: 0.9200 - val_loss: 1.6872 - val_accuracy: 0.7300
# Epoch 24/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2155 - accuracy: 0.9175 - val_loss: 1.2546 - val_accuracy: 0.7450
# Epoch 25/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1956 - accuracy: 0.9250 - val_loss: 1.4800 - val_accuracy: 0.7400
# Epoch 26/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1958 - accuracy: 0.9237 - val_loss: 1.5307 - val_accuracy: 0.7350
# Epoch 27/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1495 - accuracy: 0.9312 - val_loss: 1.5985 - val_accuracy: 0.7350
# Epoch 28/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1682 - accuracy: 0.9275 - val_loss: 1.5634 - val_accuracy: 0.7300
# Epoch 29/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1603 - accuracy: 0.9325 - val_loss: 1.8032 - val_accuracy: 0.7200
# Epoch 30/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1673 - accuracy: 0.9200 - val_loss: 1.4037 - val_accuracy: 0.7200
# Epoch 31/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1285 - accuracy: 0.9450 - val_loss: 1.7616 - val_accuracy: 0.7350
# Epoch 32/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1677 - accuracy: 0.9337 - val_loss: 1.6090 - val_accuracy: 0.7450
# Epoch 33/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1747 - accuracy: 0.9287 - val_loss: 1.5421 - val_accuracy: 0.7200
# Epoch 34/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1470 - accuracy: 0.9362 - val_loss: 1.8617 - val_accuracy: 0.7550
# Epoch 35/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1391 - accuracy: 0.9388 - val_loss: 2.0371 - val_accuracy: 0.7400
# Epoch 36/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1240 - accuracy: 0.9400 - val_loss: 1.9173 - val_accuracy: 0.7550
# Epoch 37/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1759 - accuracy: 0.9413 - val_loss: 1.8076 - val_accuracy: 0.7400
# Epoch 38/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1515 - accuracy: 0.9450 - val_loss: 1.9843 - val_accuracy: 0.7200
# Epoch 39/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1414 - accuracy: 0.9413 - val_loss: 1.9089 - val_accuracy: 0.7350
# Epoch 40/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1733 - accuracy: 0.9275 - val_loss: 1.8042 - val_accuracy: 0.7500
# Epoch 41/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.3145 - accuracy: 0.9025 - val_loss: 1.5998 - val_accuracy: 0.7450
# Epoch 42/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1817 - accuracy: 0.9137 - val_loss: 1.9222 - val_accuracy: 0.7450
# Epoch 43/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1684 - accuracy: 0.9337 - val_loss: 2.1326 - val_accuracy: 0.7400
# Epoch 44/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1398 - accuracy: 0.9413 - val_loss: 2.0059 - val_accuracy: 0.7450
# Epoch 45/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2156 - accuracy: 0.9237 - val_loss: 1.7853 - val_accuracy: 0.7550
# Epoch 46/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1693 - accuracy: 0.9350 - val_loss: 2.0234 - val_accuracy: 0.7150
# Epoch 47/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2715 - accuracy: 0.9225 - val_loss: 1.4968 - val_accuracy: 0.7400
# Epoch 48/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1625 - accuracy: 0.9262 - val_loss: 1.7899 - val_accuracy: 0.7450
# Epoch 49/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1284 - accuracy: 0.9375 - val_loss: 1.9347 - val_accuracy: 0.7600
# Epoch 50/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1371 - accuracy: 0.9350 - val_loss: 1.8556 - val_accuracy: 0.7400
# Epoch 51/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1598 - accuracy: 0.9325 - val_loss: 1.8995 - val_accuracy: 0.7150
# Epoch 52/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.3591 - accuracy: 0.8800 - val_loss: 1.3761 - val_accuracy: 0.6950
# Epoch 53/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.3485 - accuracy: 0.8800 - val_loss: 2.1607 - val_accuracy: 0.7250
# Epoch 54/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.4215 - accuracy: 0.8675 - val_loss: 1.9942 - val_accuracy: 0.7300
# Epoch 55/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.3066 - accuracy: 0.9013 - val_loss: 2.5270 - val_accuracy: 0.6500
# Epoch 56/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.2123 - accuracy: 0.8975 - val_loss: 2.5055 - val_accuracy: 0.7300
# Epoch 57/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2689 - accuracy: 0.8925 - val_loss: 1.8407 - val_accuracy: 0.7550
# Epoch 58/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.2289 - accuracy: 0.9112 - val_loss: 2.1545 - val_accuracy: 0.7350
# Epoch 59/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1787 - accuracy: 0.9225 - val_loss: 2.2517 - val_accuracy: 0.7500
# Epoch 60/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1509 - accuracy: 0.9337 - val_loss: 2.9428 - val_accuracy: 0.7550
# Epoch 61/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1874 - accuracy: 0.9200 - val_loss: 2.8310 - val_accuracy: 0.7550
# Epoch 62/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1502 - accuracy: 0.9425 - val_loss: 2.9602 - val_accuracy: 0.7200
# Epoch 63/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1564 - accuracy: 0.9325 - val_loss: 3.0126 - val_accuracy: 0.7300
# Epoch 64/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1386 - accuracy: 0.9300 - val_loss: 2.6148 - val_accuracy: 0.7450
# Epoch 65/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1189 - accuracy: 0.9463 - val_loss: 2.9530 - val_accuracy: 0.7500
# Epoch 66/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1420 - accuracy: 0.9337 - val_loss: 2.8839 - val_accuracy: 0.7400
# Epoch 67/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1113 - accuracy: 0.9450 - val_loss: 3.1489 - val_accuracy: 0.7400
# Epoch 68/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1144 - accuracy: 0.9488 - val_loss: 2.9980 - val_accuracy: 0.7250
# Epoch 69/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1192 - accuracy: 0.9488 - val_loss: 3.1846 - val_accuracy: 0.7400
# Epoch 70/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0917 - accuracy: 0.9538 - val_loss: 3.3392 - val_accuracy: 0.7450
# Epoch 71/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1002 - accuracy: 0.9500 - val_loss: 3.3439 - val_accuracy: 0.7500
# Epoch 72/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0996 - accuracy: 0.9475 - val_loss: 3.2714 - val_accuracy: 0.7400
# Epoch 73/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1124 - accuracy: 0.9513 - val_loss: 3.0964 - val_accuracy: 0.7400
# Epoch 74/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1097 - accuracy: 0.9488 - val_loss: 3.1664 - val_accuracy: 0.7300
# Epoch 75/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0929 - accuracy: 0.9488 - val_loss: 3.1972 - val_accuracy: 0.7200
# Epoch 76/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0744 - accuracy: 0.9588 - val_loss: 3.4103 - val_accuracy: 0.7350
# Epoch 77/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0836 - accuracy: 0.9538 - val_loss: 3.5745 - val_accuracy: 0.7450
# Epoch 78/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0768 - accuracy: 0.9638 - val_loss: 3.7856 - val_accuracy: 0.7300
# Epoch 79/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0651 - accuracy: 0.9650 - val_loss: 3.9420 - val_accuracy: 0.7350
# Epoch 80/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0737 - accuracy: 0.9625 - val_loss: 3.8670 - val_accuracy: 0.7550
# Epoch 81/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0765 - accuracy: 0.9525 - val_loss: 3.9342 - val_accuracy: 0.7450
# Epoch 82/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1214 - accuracy: 0.9463 - val_loss: 3.6216 - val_accuracy: 0.7300
# Epoch 83/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1587 - accuracy: 0.9337 - val_loss: 3.0388 - val_accuracy: 0.7500
# Epoch 84/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1059 - accuracy: 0.9463 - val_loss: 3.3384 - val_accuracy: 0.7050
# Epoch 85/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0797 - accuracy: 0.9563 - val_loss: 3.8459 - val_accuracy: 0.7500
# Epoch 86/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0922 - accuracy: 0.9450 - val_loss: 3.4944 - val_accuracy: 0.7350
# Epoch 87/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0851 - accuracy: 0.9525 - val_loss: 3.4834 - val_accuracy: 0.7500
# Epoch 88/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1122 - accuracy: 0.9563 - val_loss: 3.5261 - val_accuracy: 0.7450
# Epoch 89/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1293 - accuracy: 0.9500 - val_loss: 3.0785 - val_accuracy: 0.7400
# Epoch 90/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1130 - accuracy: 0.9500 - val_loss: 3.0964 - val_accuracy: 0.7400
# Epoch 91/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1093 - accuracy: 0.9563 - val_loss: 3.4008 - val_accuracy: 0.7550
# Epoch 92/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0970 - accuracy: 0.9475 - val_loss: 3.5055 - val_accuracy: 0.7400
# Epoch 93/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0768 - accuracy: 0.9600 - val_loss: 4.0649 - val_accuracy: 0.7400
# Epoch 94/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0990 - accuracy: 0.9550 - val_loss: 3.7338 - val_accuracy: 0.7450
# Epoch 95/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0970 - accuracy: 0.9525 - val_loss: 4.2036 - val_accuracy: 0.7300
# Epoch 96/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2521 - accuracy: 0.9150 - val_loss: 3.3887 - val_accuracy: 0.7300
# Epoch 97/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1092 - accuracy: 0.9375 - val_loss: 4.3416 - val_accuracy: 0.7250
# Epoch 98/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1207 - accuracy: 0.9337 - val_loss: 4.0011 - val_accuracy: 0.7200
# Epoch 99/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1161 - accuracy: 0.9513 - val_loss: 3.7470 - val_accuracy: 0.7250
# Epoch 100/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1284 - accuracy: 0.9413 - val_loss: 2.9361 - val_accuracy: 0.7300
# Epoch 1/100
# 25/25 [==============================] - 3s 22ms/step - loss: 1.8955 - accuracy: 0.5987 - val_loss: 0.6591 - val_accuracy: 0.7350
# Epoch 2/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.4964 - accuracy: 0.7600 - val_loss: 0.5736 - val_accuracy: 0.7600
# Epoch 3/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.4160 - accuracy: 0.8138 - val_loss: 0.5909 - val_accuracy: 0.7650
# Epoch 4/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.3319 - accuracy: 0.8587 - val_loss: 0.6713 - val_accuracy: 0.7850
# Epoch 5/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2748 - accuracy: 0.8925 - val_loss: 0.7238 - val_accuracy: 0.7700
# Epoch 6/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.2683 - accuracy: 0.8850 - val_loss: 0.7064 - val_accuracy: 0.7950
# Epoch 7/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2416 - accuracy: 0.8913 - val_loss: 0.8421 - val_accuracy: 0.7800
# Epoch 8/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2146 - accuracy: 0.9187 - val_loss: 0.8866 - val_accuracy: 0.7750
# Epoch 9/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2525 - accuracy: 0.8938 - val_loss: 0.7370 - val_accuracy: 0.7500
# Epoch 10/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.2097 - accuracy: 0.9150 - val_loss: 1.1656 - val_accuracy: 0.7500
# Epoch 11/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.2257 - accuracy: 0.9275 - val_loss: 1.2019 - val_accuracy: 0.7700
# Epoch 12/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1792 - accuracy: 0.9300 - val_loss: 1.0830 - val_accuracy: 0.7700
# Epoch 13/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1507 - accuracy: 0.9475 - val_loss: 1.1927 - val_accuracy: 0.7800
# Epoch 14/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1549 - accuracy: 0.9425 - val_loss: 0.9943 - val_accuracy: 0.7850
# Epoch 15/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1461 - accuracy: 0.9425 - val_loss: 1.1145 - val_accuracy: 0.7800
# Epoch 16/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1162 - accuracy: 0.9563 - val_loss: 1.2428 - val_accuracy: 0.7450
# Epoch 17/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1386 - accuracy: 0.9513 - val_loss: 1.3127 - val_accuracy: 0.7500
# Epoch 18/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0988 - accuracy: 0.9725 - val_loss: 1.3118 - val_accuracy: 0.7800
# Epoch 19/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0934 - accuracy: 0.9613 - val_loss: 1.4745 - val_accuracy: 0.7800
# Epoch 20/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1000 - accuracy: 0.9625 - val_loss: 1.4721 - val_accuracy: 0.7600
# Epoch 21/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1365 - accuracy: 0.9625 - val_loss: 1.2884 - val_accuracy: 0.7800
# Epoch 22/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1415 - accuracy: 0.9625 - val_loss: 1.4413 - val_accuracy: 0.7750
# Epoch 23/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0695 - accuracy: 0.9737 - val_loss: 1.7884 - val_accuracy: 0.7600
# Epoch 24/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0693 - accuracy: 0.9750 - val_loss: 1.8386 - val_accuracy: 0.7600
# Epoch 25/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0859 - accuracy: 0.9775 - val_loss: 1.9360 - val_accuracy: 0.7700
# Epoch 26/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1109 - accuracy: 0.9663 - val_loss: 1.5241 - val_accuracy: 0.7700
# Epoch 27/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0866 - accuracy: 0.9725 - val_loss: 1.7236 - val_accuracy: 0.7350
# Epoch 28/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0972 - accuracy: 0.9650 - val_loss: 1.6501 - val_accuracy: 0.7600
# Epoch 29/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0803 - accuracy: 0.9700 - val_loss: 1.8676 - val_accuracy: 0.7550
# Epoch 30/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0766 - accuracy: 0.9712 - val_loss: 2.1611 - val_accuracy: 0.7750
# Epoch 31/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0900 - accuracy: 0.9675 - val_loss: 1.5169 - val_accuracy: 0.7700
# Epoch 32/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0770 - accuracy: 0.9762 - val_loss: 1.8319 - val_accuracy: 0.7600
# Epoch 33/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0554 - accuracy: 0.9837 - val_loss: 2.1308 - val_accuracy: 0.7500
# Epoch 34/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0540 - accuracy: 0.9812 - val_loss: 2.3442 - val_accuracy: 0.7650
# Epoch 35/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0832 - accuracy: 0.9700 - val_loss: 2.2569 - val_accuracy: 0.7550
# Epoch 36/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0493 - accuracy: 0.9800 - val_loss: 2.2370 - val_accuracy: 0.7650
# Epoch 37/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0421 - accuracy: 0.9812 - val_loss: 2.4008 - val_accuracy: 0.7500
# Epoch 38/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0695 - accuracy: 0.9775 - val_loss: 2.0214 - val_accuracy: 0.7700
# Epoch 39/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0520 - accuracy: 0.9825 - val_loss: 2.5065 - val_accuracy: 0.7200
# Epoch 40/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0470 - accuracy: 0.9887 - val_loss: 2.7387 - val_accuracy: 0.7450
# Epoch 41/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0870 - accuracy: 0.9750 - val_loss: 2.8243 - val_accuracy: 0.7700
# Epoch 42/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0679 - accuracy: 0.9725 - val_loss: 2.4530 - val_accuracy: 0.7850
# Epoch 43/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1335 - accuracy: 0.9712 - val_loss: 1.9511 - val_accuracy: 0.7950
# Epoch 44/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0716 - accuracy: 0.9887 - val_loss: 1.8623 - val_accuracy: 0.7700
# Epoch 45/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0615 - accuracy: 0.9737 - val_loss: 2.7808 - val_accuracy: 0.7500
# Epoch 46/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0366 - accuracy: 0.9900 - val_loss: 2.8848 - val_accuracy: 0.7600
# Epoch 47/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0617 - accuracy: 0.9750 - val_loss: 2.6829 - val_accuracy: 0.7700
# Epoch 48/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0585 - accuracy: 0.9800 - val_loss: 2.5481 - val_accuracy: 0.7600
# Epoch 49/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0405 - accuracy: 0.9837 - val_loss: 2.2608 - val_accuracy: 0.7500
# Epoch 50/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0323 - accuracy: 0.9900 - val_loss: 2.5835 - val_accuracy: 0.7800
# Epoch 51/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0450 - accuracy: 0.9912 - val_loss: 2.4433 - val_accuracy: 0.7850
# Epoch 52/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0417 - accuracy: 0.9850 - val_loss: 2.4377 - val_accuracy: 0.7850
# Epoch 53/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0339 - accuracy: 0.9875 - val_loss: 2.5468 - val_accuracy: 0.7650
# Epoch 54/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0367 - accuracy: 0.9862 - val_loss: 2.1158 - val_accuracy: 0.7800
# Epoch 55/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0320 - accuracy: 0.9887 - val_loss: 2.8497 - val_accuracy: 0.7400
# Epoch 56/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0225 - accuracy: 0.9912 - val_loss: 2.9032 - val_accuracy: 0.7600
# Epoch 57/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0326 - accuracy: 0.9875 - val_loss: 2.6769 - val_accuracy: 0.7750
# Epoch 58/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0192 - accuracy: 0.9925 - val_loss: 2.8167 - val_accuracy: 0.7750
# Epoch 59/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0256 - accuracy: 0.9937 - val_loss: 2.9206 - val_accuracy: 0.7550
# Epoch 60/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0293 - accuracy: 0.9912 - val_loss: 3.1983 - val_accuracy: 0.7500
# Epoch 61/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0405 - accuracy: 0.9887 - val_loss: 3.2392 - val_accuracy: 0.7750
# Epoch 62/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0433 - accuracy: 0.9887 - val_loss: 3.2892 - val_accuracy: 0.7600
# Epoch 63/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0306 - accuracy: 0.9912 - val_loss: 3.6385 - val_accuracy: 0.7650
# Epoch 64/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0361 - accuracy: 0.9900 - val_loss: 3.4060 - val_accuracy: 0.7700
# Epoch 65/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0344 - accuracy: 0.9900 - val_loss: 3.3695 - val_accuracy: 0.7800
# Epoch 66/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0527 - accuracy: 0.9900 - val_loss: 3.5522 - val_accuracy: 0.7450
# Epoch 67/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0287 - accuracy: 0.9887 - val_loss: 3.4044 - val_accuracy: 0.7800
# Epoch 68/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0336 - accuracy: 0.9912 - val_loss: 3.5390 - val_accuracy: 0.7700
# Epoch 69/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0192 - accuracy: 0.9937 - val_loss: 3.7384 - val_accuracy: 0.7700
# Epoch 70/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0188 - accuracy: 0.9900 - val_loss: 4.0666 - val_accuracy: 0.7800
# Epoch 71/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0421 - accuracy: 0.9862 - val_loss: 3.2474 - val_accuracy: 0.7800
# Epoch 72/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1117 - accuracy: 0.9725 - val_loss: 2.8445 - val_accuracy: 0.7550
# Epoch 73/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0429 - accuracy: 0.9875 - val_loss: 3.1194 - val_accuracy: 0.7700
# Epoch 74/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0682 - accuracy: 0.9800 - val_loss: 3.1037 - val_accuracy: 0.7450
# Epoch 75/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0384 - accuracy: 0.9850 - val_loss: 3.3962 - val_accuracy: 0.7400
# Epoch 76/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1119 - accuracy: 0.9825 - val_loss: 2.3091 - val_accuracy: 0.7650
# Epoch 77/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0406 - accuracy: 0.9862 - val_loss: 3.3162 - val_accuracy: 0.7600
# Epoch 78/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0318 - accuracy: 0.9937 - val_loss: 3.1159 - val_accuracy: 0.7600
# Epoch 79/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0599 - accuracy: 0.9837 - val_loss: 2.5822 - val_accuracy: 0.7750
# Epoch 80/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0131 - accuracy: 0.9950 - val_loss: 3.1933 - val_accuracy: 0.7750
# Epoch 81/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0167 - accuracy: 0.9937 - val_loss: 3.2309 - val_accuracy: 0.7800
# Epoch 82/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0352 - accuracy: 0.9887 - val_loss: 2.7719 - val_accuracy: 0.7800
# Epoch 83/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0346 - accuracy: 0.9887 - val_loss: 2.6902 - val_accuracy: 0.7750
# Epoch 84/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0268 - accuracy: 0.9912 - val_loss: 2.9909 - val_accuracy: 0.7700
# Epoch 85/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0150 - accuracy: 0.9950 - val_loss: 2.9795 - val_accuracy: 0.7800
# Epoch 86/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0182 - accuracy: 0.9937 - val_loss: 3.2291 - val_accuracy: 0.7650
# Epoch 87/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0109 - accuracy: 0.9962 - val_loss: 3.3586 - val_accuracy: 0.7700
# Epoch 88/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0113 - accuracy: 0.9962 - val_loss: 3.4185 - val_accuracy: 0.7750
# Epoch 89/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0140 - accuracy: 0.9925 - val_loss: 3.4092 - val_accuracy: 0.7950
# Epoch 90/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0188 - accuracy: 0.9925 - val_loss: 3.2494 - val_accuracy: 0.7950
# Epoch 91/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0182 - accuracy: 0.9925 - val_loss: 3.4638 - val_accuracy: 0.7750
# Epoch 92/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0344 - accuracy: 0.9875 - val_loss: 3.7155 - val_accuracy: 0.7850
# Epoch 93/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0627 - accuracy: 0.9887 - val_loss: 4.3364 - val_accuracy: 0.7800
# Epoch 94/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0456 - accuracy: 0.9837 - val_loss: 4.2523 - val_accuracy: 0.7750
# Epoch 95/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0373 - accuracy: 0.9900 - val_loss: 4.0816 - val_accuracy: 0.7700
# Epoch 96/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0691 - accuracy: 0.9875 - val_loss: 4.0347 - val_accuracy: 0.7800
# Epoch 97/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0693 - accuracy: 0.9825 - val_loss: 3.9869 - val_accuracy: 0.7600
# Epoch 98/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0866 - accuracy: 0.9725 - val_loss: 3.3156 - val_accuracy: 0.7700
# Epoch 99/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0464 - accuracy: 0.9862 - val_loss: 3.6836 - val_accuracy: 0.7700
# Epoch 100/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0369 - accuracy: 0.9837 - val_loss: 3.1855 - val_accuracy: 0.7600

# %%
# Concatenate the outputs of the two models
merged = Concatenate()([model1.output, model2.output])

# Add more layers 
x = Dense(64, activation='relu')(merged)
final_output = Dense(1, activation='sigmoid')(x)

autoencoder = Model(inputs=[model1.input, model2.input], outputs=final_output)

# Compile the model
autoencoder.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
autoencoder.fit([data, data_deriv], np.array(labels), epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 5s 21ms/step - loss: 0.6698 - accuracy: 0.4770
# Epoch 2/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.5964 - accuracy: 0.5400
# Epoch 3/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.5418 - accuracy: 0.8780
# Epoch 4/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.4927 - accuracy: 0.9470
# Epoch 5/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.4623 - accuracy: 0.9320
# Epoch 6/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.4240 - accuracy: 0.9410
# Epoch 7/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.4130 - accuracy: 0.9260
# Epoch 8/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3882 - accuracy: 0.9240
# Epoch 9/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3692 - accuracy: 0.9210
# Epoch 10/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3541 - accuracy: 0.9120
# Epoch 11/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3515 - accuracy: 0.9130
# Epoch 12/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3283 - accuracy: 0.9080
# Epoch 13/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3187 - accuracy: 0.9230
# Epoch 14/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2670 - accuracy: 0.9400
# Epoch 15/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3150 - accuracy: 0.9080
# Epoch 16/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3331 - accuracy: 0.9010
# Epoch 17/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3323 - accuracy: 0.8980
# Epoch 18/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3699 - accuracy: 0.8800
# Epoch 19/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.4815 - accuracy: 0.8110
# Epoch 20/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3770 - accuracy: 0.8690
# Epoch 21/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3797 - accuracy: 0.8690
# Epoch 22/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3345 - accuracy: 0.8930
# Epoch 23/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3519 - accuracy: 0.8900
# Epoch 24/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3407 - accuracy: 0.8930
# Epoch 25/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3266 - accuracy: 0.8970
# Epoch 26/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2799 - accuracy: 0.9200
# Epoch 27/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2863 - accuracy: 0.9150
# Epoch 28/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2911 - accuracy: 0.9110
# Epoch 29/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2976 - accuracy: 0.9160
# Epoch 30/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2818 - accuracy: 0.9230
# Epoch 31/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3574 - accuracy: 0.8790
# Epoch 32/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3139 - accuracy: 0.8970
# Epoch 33/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3057 - accuracy: 0.9080
# Epoch 34/100
# 32/32 [==============================] - 1s 17ms/step - loss: 0.3000 - accuracy: 0.9070
# Epoch 35/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2920 - accuracy: 0.9110
# Epoch 36/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3191 - accuracy: 0.9050
# Epoch 37/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3539 - accuracy: 0.8860
# Epoch 38/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3016 - accuracy: 0.9120
# Epoch 39/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2876 - accuracy: 0.9160
# Epoch 40/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3184 - accuracy: 0.9030
# Epoch 41/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3526 - accuracy: 0.8860
# Epoch 42/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.4222 - accuracy: 0.8460
# Epoch 43/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3329 - accuracy: 0.8970
# Epoch 44/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3198 - accuracy: 0.9010
# Epoch 45/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3025 - accuracy: 0.9110
# Epoch 46/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3900 - accuracy: 0.8670
# Epoch 47/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3408 - accuracy: 0.8890
# Epoch 48/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3430 - accuracy: 0.8900
# Epoch 49/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3508 - accuracy: 0.8850
# Epoch 50/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3418 - accuracy: 0.8870
# Epoch 51/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3592 - accuracy: 0.8760
# Epoch 52/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3408 - accuracy: 0.8980
# Epoch 53/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3477 - accuracy: 0.8910
# Epoch 54/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3785 - accuracy: 0.8740
# Epoch 55/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3935 - accuracy: 0.8650
# Epoch 56/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3319 - accuracy: 0.8950
# Epoch 57/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3178 - accuracy: 0.9010
# Epoch 58/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2934 - accuracy: 0.9130
# Epoch 59/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3101 - accuracy: 0.9090
# Epoch 60/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2733 - accuracy: 0.9240
# Epoch 61/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3038 - accuracy: 0.9100
# Epoch 62/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3336 - accuracy: 0.8960
# Epoch 63/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3991 - accuracy: 0.8610
# Epoch 64/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3577 - accuracy: 0.8890
# Epoch 65/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.4357 - accuracy: 0.8410
# Epoch 66/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3404 - accuracy: 0.8950
# Epoch 67/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3104 - accuracy: 0.9080
# Epoch 68/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2990 - accuracy: 0.9120
# Epoch 69/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3111 - accuracy: 0.9080
# Epoch 70/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3564 - accuracy: 0.8840
# Epoch 71/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3162 - accuracy: 0.9060
# Epoch 72/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2965 - accuracy: 0.9120
# Epoch 73/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2963 - accuracy: 0.9110
# Epoch 74/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3307 - accuracy: 0.8960
# Epoch 75/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2663 - accuracy: 0.9270
# Epoch 76/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3012 - accuracy: 0.9110
# Epoch 77/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3034 - accuracy: 0.9100
# Epoch 78/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2763 - accuracy: 0.9210
# Epoch 79/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2899 - accuracy: 0.9150
# Epoch 80/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2736 - accuracy: 0.9210
# Epoch 81/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2847 - accuracy: 0.9160
# Epoch 82/100
# 32/32 [==============================] - 1s 17ms/step - loss: 0.2565 - accuracy: 0.9290
# Epoch 83/100
# 32/32 [==============================] - 1s 17ms/step - loss: 0.2821 - accuracy: 0.9180
# Epoch 84/100
# 32/32 [==============================] - 1s 17ms/step - loss: 0.3248 - accuracy: 0.9030
# Epoch 85/100
# 32/32 [==============================] - 1s 17ms/step - loss: 0.4088 - accuracy: 0.8570
# Epoch 86/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.5565 - accuracy: 0.7250
# Epoch 87/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.4999 - accuracy: 0.7750
# Epoch 88/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3536 - accuracy: 0.8870
# Epoch 89/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3198 - accuracy: 0.9020
# Epoch 90/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3225 - accuracy: 0.9020
# Epoch 91/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.2981 - accuracy: 0.9120
# Epoch 92/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3050 - accuracy: 0.9090
# Epoch 93/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3125 - accuracy: 0.9030
# Epoch 94/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3871 - accuracy: 0.8600
# Epoch 95/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3069 - accuracy: 0.9030
# Epoch 96/100
# 32/32 [==============================] - 1s 17ms/step - loss: 0.3006 - accuracy: 0.9140
# Epoch 97/100
# 32/32 [==============================] - 1s 18ms/step - loss: 0.3377 - accuracy: 0.8960
# Epoch 98/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3184 - accuracy: 0.9030
# Epoch 99/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3631 - accuracy: 0.8820
# Epoch 100/100
# 32/32 [==============================] - 1s 19ms/step - loss: 0.3818 - accuracy: 0.8670

# %%
# Anomaly Detection of Processed Flares
norminfo = pd.read_csv('allflares_processed.csv')
idsnorm = [i for i in norminfo['identifier']]
peak_count = [int(count) for count in norminfo['peak_count']]

datanorm = []
labelsnorm = []

for i in idsnorm:
    tod = pd.read_csv('flares/' + f'{i}' + '.csv')
    datanorm.append(list(tod['Counts']))
    
for index in range(len(norminfo)):
    if str(norminfo['flare_type'][index]) == 'A':
        labelsnorm.append(0)
    if str(norminfo['flare_type'][index]) == 'B':
        labelsnorm.append(1)
    else:
        continue
datanorm = pad_sequences(datanorm, padding='post', dtype=float, maxlen=1999)

datanorm_deriv = [ (datanorm[i][1:] - datanorm[i][:-1]) for i in range(len(datanorm)) ] 
datanorm_deriv = pad_sequences(datanorm_deriv, padding='post', dtype=float)
print(datanorm.shape)
print(datanorm_deriv.shape)
print(type(datanorm_deriv[0,0]))
# Out:
# (1091, 1999)
# (1091, 1998)
# <class 'numpy.float64'>

# %%
datanorm_expanded = np.expand_dims(datanorm, axis=-1)
datanorm_deriv_expanded = np.expand_dims(datanorm_deriv, axis=-1)

# Use the autoencoder to reconstruct the inputs based on model data
recondata = autoencoder.predict([datanorm_expanded, datanorm_deriv_expanded])

# Compute reconstruction errors
reconerror = np.mean(np.square(recondata - datanorm) , axis=1)

# Anomaly detection based on reconstruction error
threshold = (np.mean(reconerror) + (3 * np.std(reconerror))) 
anomalies = reconerror > threshold

print(f'Size of Testing Data = {anomalies.size}')
print(f'Number of Anomalies Detected = {np.sum(anomalies)}')
print(f'Percent Anomalies = {(np.sum(anomalies) / anomalies.size)}')
# Out:
# 35/35 [==============================] - 1s 9ms/step
# Size of Testing Data = 1091
# Number of Anomalies Detected = 10
# Percent Anomalies = 0.00916590284142988

# %%
try:
    anomcsv = pd.read_csv('anomalies.csv')
except FileNotFoundError:
    anomcsv = pd.DataFrame(columns=norminfo.columns)
    
# Plotting anomalies
for i, recondata in enumerate(tqdm(datanorm)):
    recondata_class = int(np.round(recondata[0]))
    if anomalies[i] == True:
        plt.plot(np.arange(0, len(datanorm[i][datanorm[i] != 0]))*10, datanorm[i][datanorm[i] != 0])
        plt.xlabel('Time')
        plt.ylabel('Count')
        plt.title(f"{idsnorm[i]}")
        plt.show()
        
        # Saving anomalies to CSV
        anomcsv = pd.concat([anomcsv, norminfo.iloc[[i]]], ignore_index=True)
        anomcsv.to_csv('anomalies.csv', index=False)

# Saving anomaly flares to anomaly_flares
os.makedirs('anomaly_flares', exist_ok=True)
anomalinfo = pd.read_csv('anomalies.csv')
anomids = [i for i in anomalinfo['identifier']]
for i in anomids:
    flare = pd.read_csv('flares/' + f'{i}' + '.csv')
    flare.to_csv('anomaly_flares/' + f'{i}' + '.csv', index=False)
# Out:
#   0%|          | 0/1091 [00:00<?, ?it/s]
#   6%|▌         | 67/1091 [00:00<00:02, 360.71it/s]
#  11%|█▏        | 124/1091 [00:00<00:02, 386.88it/s]
#  15%|█▌        | 164/1091 [00:00<00:03, 245.39it/s]
#  19%|█▉        | 209/1091 [00:00<00:03, 292.57it/s]
#  22%|██▏       | 244/1091 [00:00<00:03, 268.42it/s]
#  26%|██▌       | 284/1091 [00:01<00:02, 270.15it/s]
#  29%|██▉       | 317/1091 [00:01<00:02, 265.41it/s]
# 100%|██████████| 1091/1091 [00:01<00:00, 762.87it/s]

# %%
# ROC and AUC of Processed Flares
fpr, tpr, thresholds = roc_curve(labelsnorm, reconerror)

plt.figure()
plt.plot(tpr, fpr, label=f"MSE loss, AUC={auc(fpr, tpr)*100:.2f}%")
plt.semilogy()
plt.legend(title="Autoencoder")
plt.xlabel("True positive rate")
plt.ylabel("False positive rate")
plt.grid()
plt.title("Processed Flares")
plt.show()

# %%
# Anomaly Detection of Pre-Processed Flares
norminfo = pd.read_csv('allflares_preprocessed.csv')
idsnorm = [i for i in norminfo['identifier']]
peak_count = [int(count) for count in norminfo['peak_count']]

datanorm = []
labelsnorm = []

for i in idsnorm:
    tod = pd.read_csv('flares/' + f'{i}' + '.csv')
    datanorm.append(list(tod['Counts']))
    
for index in range(len(norminfo)):
    if str(norminfo['flare_type'][index]) == 'A':
        labelsnorm.append(0)
    else:
        labelsnorm.append(1)
        continue
datanorm = pad_sequences(datanorm, padding='post', dtype=float, maxlen=1999)   # the padding is to adjust the shape of the np arrays

datanorm_deriv = [ (datanorm[i][1:] - datanorm[i][:-1]) for i in range(len(datanorm)) ] 
datanorm_deriv = pad_sequences(datanorm_deriv, padding='post', dtype=float)
print(datanorm.shape)
print(datanorm_deriv.shape)
print(type(datanorm_deriv[0,0]))
# Out:
# (8045, 1999)
# (8045, 1998)
# <class 'numpy.float64'>

# %%
datanorm_expanded = np.expand_dims(datanorm, axis=-1)
datanorm_deriv_expanded = np.expand_dims(datanorm_deriv, axis=-1)

# Use the autoencoder to reconstruct the inputs based on model data
recondata = autoencoder.predict([datanorm_expanded, datanorm_deriv_expanded])

# Compute reconstruction errors
reconerror = np.mean(np.square(recondata - datanorm) , axis=1)

# Anomaly detection based on reconstruction error
threshold = (np.mean(reconerror) + (3 * np.std(reconerror))) 
anomalies = reconerror > threshold

print(f'Size of Testing Data = {anomalies.size}')
print(f'Number of Anomalies Detected = {np.sum(anomalies)}')
print(f'Percent Anomalies = {(np.sum(anomalies) / anomalies.size)}')
# Out:
# 252/252 [==============================] - 2s 6ms/step
# Size of Testing Data = 8045
# Number of Anomalies Detected = 46
# Percent Anomalies = 0.005717837165941579

# %%
# ROC and AUC of Pre-Processed Flares
fpr, tpr, thresholds = roc_curve(labelsnorm, reconerror)

plt.figure()
plt.plot(tpr, fpr, label=f"MSE loss, AUC={auc(fpr, tpr)*100:.2f}%")
plt.semilogy()
plt.legend(title="Autoencoder")
plt.xlabel("True positive rate")
plt.ylabel("False positive rate")
plt.grid()
plt.title("Pre-Processed Flares")
plt.show()
